# %%
import pyforest

# %%
df = pd.read_csv('day_wise.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
df.shape
# Out:
# (188, 12)

# %% [markdown]
# ## Corelation between Confirmed and Recovered

# %%
plt.style.use('fivethirtyeight')
sns.relplot(data=df, x='New cases', y='New recovered',height=7)
plt.show()

# %% [markdown]
# ## Corelation between Confirmed and Deaths

# %%
plt.style.use('fivethirtyeight')
sns.relplot(data=df, x='New cases', y='New deaths',color='r',height=7)
plt.show()

# %% [markdown]
# ## Pie chart

# %%
total_cases = df['New cases'].sum()
total_recovered = df['New recovered'].sum()
total_deaths = df['New deaths'].sum()

# %%
plt.style.use('fivethirtyeight')
data = [total_cases, total_recovered, total_deaths]
colors = ['#17a2b8', '#28a745', '#dc3545']
labels = ['Total Cases','Total Recovered','Total Deaths']
plt.pie(data,colors=colors,autopct='%.1f%%',labels=labels)
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %% [markdown]
# ## Cases and Countries

# %%
plt.style.use('fivethirtyeight')
sns.relplot(data=df,x="No. of countries",y="New cases",height=7,kind='line',aspect=1,linewidth=1)
plt.show()

# %% [markdown]
# ## Cases per 100

# %%
#column names
deaths = 'Deaths / 100 Cases'
recovered = 'Recovered / 100 Cases'
x_axis = [i for i in range(188)]

# %%
plt.style.use('dark_background')
plt.plot(x_axis,df[deaths],'r',linewidth=1,label="Deaths")
plt.plot(x_axis,df[recovered],'g',linewidth=1,label="Recovered")

plt.title('Cases/100')
plt.xlabel('Number of days')
plt.ylabel('Cases')
plt.legend()
plt.show()
